# %% [markdown]
# # Step 2: Data Cleaning & Preparation

# %%
# Import necessary libraries
import pandas as pd

# %% [markdown]
# ## A. Grocery Market Data

# %%
# Create dataframe from USDA data
usda_df = pd.read_csv('MNRetailDatasetCSV.CSV')
# Out:
# /var/folders/zf/cb3_1h9969d8z3n17n7d956r0000gn/T/ipykernel_12666/636022322.py:2: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   usda_df = pd.read_csv('MNRetailDatasetCSV.CSV')

# %%
# Take a look at what needs done
usda_df.head()
# Out:
#   LEVEL_OF_TRADE FREQUENCY  ISSUING_OFFICE REPORT_DATE  PROGRAM LEVEL_1  \
# 0         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
# 1         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
# 2         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
# 3         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
# 4         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
#
#   LEVEL_2 LEVEL_3    LEVEL_4 LEVEL_5  ... STORES_WITH_ADS STORE_OUTLETS  \
# 0     NaN  LIQUID        NaN     NaN  ...             NaN        5500.0
# 1     NaN  LIQUID        NaN     NaN  ...             NaN        5500.0
# 2     NaN  LIQUID        NaN     NaN  ...             NaN       29200.0
# 3     NaN  LIQUID        NaN     NaN  ...             NaN       29200.0
# 4     NaN   SHELL  ALL SHELL     NaN  ...             NaN         100.0
#
#   FEATURE_RATE SPECIAL_RATE  ACTIVITY_INDEX  LOCALLY_GROWN_PERCENTAGE  \
# 0          NaN          NaN            65.0                       NaN
# 1          1.2          NaN             NaN                       NaN
# 2          NaN          NaN            65.0                       NaN
# 3          0.2          NaN             NaN                       NaN
# 4          NaN         11.0             NaN                       NaN
#
#    WEIGHTED_AVERAGE_PRICE  PRICE_LOW  PRICE_HIGH  PRODUCT_QUALITY
# 0                     NaN        NaN         NaN              NaN
# 1                     NaN        NaN         NaN              NaN
# 2                     NaN        NaN         NaN              NaN
# 3                     NaN        NaN         NaN              NaN
# 4                     NaN        NaN         NaN              NaN
#
# [5 rows x 24 columns]

# %%
# Looks like columns need standardized to snake_case
usda_df.columns = usda_df.columns.str.lower()

usda_df.head()
# Out:
#   level_of_trade frequency  issuing_office report_date  program level_1  \
# 0         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
# 1         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
# 2         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
# 3         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
# 4         RETAIL    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS
#
#   level_2 level_3    level_4 level_5  ... stores_with_ads store_outlets  \
# 0     NaN  LIQUID        NaN     NaN  ...             NaN        5500.0
# 1     NaN  LIQUID        NaN     NaN  ...             NaN        5500.0
# 2     NaN  LIQUID        NaN     NaN  ...             NaN       29200.0
# 3     NaN  LIQUID        NaN     NaN  ...             NaN       29200.0
# 4     NaN   SHELL  ALL SHELL     NaN  ...             NaN         100.0
#
#   feature_rate special_rate  activity_index  locally_grown_percentage  \
# 0          NaN          NaN            65.0                       NaN
# 1          1.2          NaN             NaN                       NaN
# 2          NaN          NaN            65.0                       NaN
# 3          0.2          NaN             NaN                       NaN
# 4          NaN         11.0             NaN                       NaN
#
#    weighted_average_price  price_low  price_high  product_quality
# 0                     NaN        NaN         NaN              NaN
# 1                     NaN        NaN         NaN              NaN
# 2                     NaN        NaN         NaN              NaN
# 3                     NaN        NaN         NaN              NaN
# 4                     NaN        NaN         NaN              NaN
#
# [5 rows x 24 columns]

# %%
# What's going on in the level_of_trade column?
usda_df['level_of_trade'].unique()

# If the only value in the column is 'RETAIL', then it seens like it can be dropped
usda_df.drop('level_of_trade', axis=1, inplace=True)

usda_df.head()
# Out:
#   frequency  issuing_office report_date  program level_1 level_2 level_3  \
# 0    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN  LIQUID
# 1    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN  LIQUID
# 2    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN  LIQUID
# 3    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN  LIQUID
# 4    WEEKLY  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN   SHELL
#
#      level_4 level_5 organic  ... stores_with_ads store_outlets feature_rate  \
# 0        NaN     NaN      NO  ...             NaN        5500.0          NaN
# 1        NaN     NaN      NO  ...             NaN        5500.0          1.2
# 2        NaN     NaN      NO  ...             NaN       29200.0          NaN
# 3        NaN     NaN      NO  ...             NaN       29200.0          0.2
# 4  ALL SHELL     NaN      NO  ...             NaN         100.0          NaN
#
#    special_rate  activity_index  locally_grown_percentage  \
# 0           NaN            65.0                       NaN
# 1           NaN             NaN                       NaN
# 2           NaN            65.0                       NaN
# 3           NaN             NaN                       NaN
# 4          11.0             NaN                       NaN
#
#    weighted_average_price  price_low  price_high  product_quality
# 0                     NaN        NaN         NaN              NaN
# 1                     NaN        NaN         NaN              NaN
# 2                     NaN        NaN         NaN              NaN
# 3                     NaN        NaN         NaN              NaN
# 4                     NaN        NaN         NaN              NaN
#
# [5 rows x 23 columns]

# %%
# What's going on in the frequency column?
usda_df['frequency'].unique()

# Only 'WEEKLY'.  Can be dropped.
usda_df.drop('frequency', axis=1, inplace=True)

usda_df.head()
# Out:
#    issuing_office report_date  program level_1 level_2 level_3    level_4  \
# 0  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN  LIQUID        NaN
# 1  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN  LIQUID        NaN
# 2  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN  LIQUID        NaN
# 3  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN  LIQUID        NaN
# 4  DES MOINES, IA   30-AUG-24  POULTRY    EGGS     NaN   SHELL  ALL SHELL
#
#   level_5 organic specialty  ... stores_with_ads store_outlets  feature_rate  \
# 0     NaN      NO       NO   ...             NaN        5500.0           NaN
# 1     NaN      NO       NO   ...             NaN        5500.0           1.2
# 2     NaN      NO       NO   ...             NaN       29200.0           NaN
# 3     NaN      NO       NO   ...             NaN       29200.0           0.2
# 4     NaN      NO       NO   ...             NaN         100.0           NaN
#
#    special_rate  activity_index  locally_grown_percentage  \
# 0           NaN            65.0                       NaN
# 1           NaN             NaN                       NaN
# 2           NaN            65.0                       NaN
# 3           NaN             NaN                       NaN
# 4          11.0             NaN                       NaN
#
#    weighted_average_price  price_low  price_high  product_quality
# 0                     NaN        NaN         NaN              NaN
# 1                     NaN        NaN         NaN              NaN
# 2                     NaN        NaN         NaN              NaN
# 3                     NaN        NaN         NaN              NaN
# 4                     NaN        NaN         NaN              NaN
#
# [5 rows x 22 columns]

# %%
# What's going on in issueing_office? 
usda_df['issuing_office'].unique()

# Huh... that's a surprisingly small number of different offices listed.  Still useful to keep, though.
# Out:
# array(['DES MOINES, IA', 'ST JOSEPH, MO', 'IDAHO FALLS, CA'], dtype=object)

# %%
# What's going on in report_date?
usda_df['report_date'].unique()

# Gez... how many unique dates are in this column?
usda_df['report_date'].nunique()

# 252.  What's the earliest date and the latest date?
usda_df['report_date'] = pd.to_datetime(usda_df['report_date'])
earleist_date = usda_df['report_date'].min()
latest_date = usda_df['report_date'].max()

print(earleist_date)
print(latest_date)

# Looks like we have 2020-01-03 to 2024-08-30 in this dataset.
# Out:
# /var/folders/zf/cb3_1h9969d8z3n17n7d956r0000gn/T/ipykernel_12666/3073408268.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   usda_df['report_date'] = pd.to_datetime(usda_df['report_date'])
# 2020-01-03 00:00:00
# 2024-08-30 00:00:00

# %%
# What's going on in program?
usda_df['program'].unique()

# Just 3 values, eh... I was expecting more.  I guess we'll see what's in level_1, etc.
# Do we need this column???
# Out:
# array(['POULTRY', 'LIVESTOCK', 'FRUITVEG'], dtype=object)

# %%
# What's going on in level_1?
usda_df['level_1'].nunique()

# 82 unique values.  What kinds of values do we have?
usda_df['level_1'].unique()
# Out:
# array(['EGGS', 'TURKEY', 'CHICKEN', 'PORK', 'LAMB/VEAL', 'BEEF',
#        'ROSE, HYBRID TEA', 'POTATOES', 'POTTED PLANTS', 'PLUMS',
#        'PINEAPPLES', 'PEPPERS, OTHER', 'PEARS', 'PEPPERS, BELL TYPE',
#        'PEACHES', nan, 'ORANGES', 'ONIONS, DRY', 'LIMES', 'LEMONS',
#        'CUCUMBERS', 'CELERY', 'CABBAGE', 'BEANS', 'BANANAS', 'ASPARAGUS',
#        'ARTICHOKES', 'APPLES', 'ONIONS GREEN', 'NECTARINES', 'MUSHROOMS',
#        'LETTUCE, ICEBERG', 'KIWIFRUIT', 'HONEYDEWS', 'GRAPES', 'GREENS',
#        'GLADIOLA', 'FRUIT, OTHER', 'CORN-SWEET', 'CLEMENTINES',
#        'CHERRIES', 'CAULIFLOWER', 'CARROTS', 'CANTALOUPS', 'BROCCOLI',
#        'AVOCADOS', 'TOMATOES', 'SQUASH', 'RADISHES',
#        'TOMATOES, PLUM TYPE', 'TOMATOES, CHERRY', 'TOMATOES, GRAPE TYPE',
#        'MISC BERRIES', 'GARLIC', 'TANGELOS', 'SWEET POTATOES',
#        'STRAWBERRIES', 'PRUNES', 'MANGOES', 'LETTUCE, ROMAINE',
#        'LETTUCE, OTHER', 'GRAPEFRUIT', 'EGGPLANT', 'CILANTRO',
#        'CHINESE CABBAGE', 'BRUSSELS SPROUTS', 'BLUEBERRIES', 'BOK CHOY',
#        'WATERMELONS', 'TOMATILLOS', 'TULIPS', 'TANGERINES', 'SPINACH',
#        'SALAD', 'RASPBERRIES', 'PUMPKINS', 'APRICOTS', 'MISC CITRUS',
#        'POMEGRANATES', 'DAFFODIL', 'PERSIMMONS', 'MISC. CHRISTMAS ITEMS',
#        'CRANBERRIES'], dtype=object)

# %%
# What's going on in level_2?
usda_df['level_2'].unique()

# How much of this column is NaN? 
nan_percentage = usda_df['level_2'].isna().sum() / len(usda_df['level_2']) * 100
print(nan_percentage)

# 8.06%.  Do we need these sub-categories on items, though? 
# Guess I'll keep it for now...
# Out:
# array([nan, 'PREPARED', 'FRESH/FROZEN/PREPARED', 'FRESH', 'FROZEN',
#        'FRESH/FROZEN', 'FILET MIGNON', 'TENDERLOIN', 'FLANK STEAK',
#        'PORTERHOUSE STEAK', 'BNLS RIBEYE STEAK',
#        'BNLS NEW YORK STRIP STEAK', 'BNLS RIBEYE ROAST',
#        'BONE-IN STRIP STEAK', 'BONE-IN RIBEYE STEAK',
#        'BNLS TOP SIRLOIN STEAK', 'SKIRT STEAK', 'BNLS SIRLOIN STEAK',
#        'BRISKET, FLAT', 'T-BONE STEAK', 'LOIN, BNLS', 'BEEF SHORT RIBS',
#        'TOP ROUND STEAK', 'BNLS TOP SIRLOIN ROAST', 'SIRLOIN STEAK',
#        'MINUTE/CUBE STEAKS', 'SIRLOIN TIP STEAK', 'EYE OF ROUND STEAK',
#        'STEW MEAT', 'TRI-TIP', 'TOP ROUND ROAST', 'BEEF PATTIES',
#        'BOTTOM ROUND ROAST', 'SIRLOIN TIP ROAST', 'LONDON BROIL',
#        'EYE OF ROUND ROAST', 'GROUND SIRLOIN', 'GROUND BEEF 90% OR MORE',
#        'CHUCK/SHLDR/ARM ROAST', 'BOTTOM ROUND STEAK',
#        'CHUCK/SHLDR/ARM STEAK', 'RUMP ROAST', 'GROUND ROUND', 'BRISKET',
#        'BEEF BACKRIBS', 'GROUND BEEF 80-89%', 'GROUND CHUCK',
#        'GROUND BEEF 70-79%', 'PRE-COOKED BACON', 'CANADIAN BACON',
#        'PKG/SLCD HAM, 1 LB/LESS', 'DELI HAM', 'DELI COOKED BACKRIBS',
#        'DELI COOKED PORK ROAST', 'SMOKED CHOPS', 'DELI COOKED SPARERIBS',
#        'PRE-COOKED SAUSAGE', 'SLICED BACON, 1 LB PKG',
#        'TENDERLOIN, MARINATED', 'PULLED PORK', 'HAM, BNLS',
#        'BKFST SAUSAGE, LINK/PATTY', 'HAM STEAK', 'DINNER SAUSAGE',
#        'CC CHOPS BNLS', 'BKFST SAUSAGE, 1 LB ROLL', 'GROUND PORK',
#        'CHORIZO', 'ITALIAN SAUSAGE', 'HAM, B/IN', 'RIB END CHOPS B/IN',
#        'TENDERLOIN, FRESH', 'BACKRIBS', 'PORKETTA', 'LOIN ROAST BNLS',
#        'RIB CHOPS BNLS', 'ASSORTED CHOPS B/IN', 'CC CHOPS B/IN',
#        'COUNTRY STYLE RIBS BNLS', 'COUNTRY STYLE RIB B/IN', 'PORK STEAK',
#        'ST. LOUIS STYLE SPARERIBS', 'SIRLOIN CHOPS BNLS', 'SPARERIBS',
#        'BONE-IN CC LOIN', 'SIRLOIN ROAST BNLS', 'BUTT ROAST BNLS', 'FEET',
#        'NECKBONES', 'BUTT FRESH B/IN', 'SIRLOIN CHOPS B/IN',
#        'SIRLOIN END ROAST B/IN', 'PICNIC FRESH B/IN', 'HAM, B/IN SHANK',
#        'HAM, B/IN BUTT', 'LB RIB CHOPS', 'VL LEG CUTLETS', 'LB RACK',
#        'VL LOIN CHOPS', 'LB LOIN CHOPS', 'VL STEW MEAT', 'VL GROUND VEAL',
#        'LB SHLDR RND BONE CHOP', 'VL SHLDR BLADE CHOPS',
#        'LB SHLDR BLADE CHOPS', 'LB SHANK', 'LB SEMI-BNLS LEG',
#        'VL BREAST', 'LB STEW MEAT-LAMB', 'LB GROUND LAMB', 'VL RIB CHOPS',
#        'LB BUTTERFLIED, BNLS LEG', 'LB STEW MEAT-MUTTON',
#        'BONE-IN RIBEYE ROAST', 'FLAT IRON STEAK', 'CORNED BEEF FLAT',
#        'BNLS SIRLOIN ROAST', 'RIB END ROAST B/IN',
#        'VL SHLDR RND BONE CHOPS', 'LB LEG STEAKS', 'LB BONELESS LEG',
#        'SIRLOIN ROAST', 'CORNED BEEF BRISKET', 'HAM, SPIRAL',
#        'WHOLE BONE-IN LOINS', 'VL BONE-IN OSSO BUCCO', 'LB BONE-IN LEG',
#        'RUMP STEAK', 'LB BREAST', 'VL SCALLOPINI', 'LB TOP ROUND STEAK',
#        'LB WHOLE LOIN', 'LB LEG, SHANK/BUTT', 'LB SHOULDER ROAST',
#        'VL BNLS ROAST', 'ROUND RED', 'RUSSET', 'CHRYSANTHEMUM',
#        'INTERSPECIFIC TYPE', 'MIXED MINI SWEET TYPES', 'JALAPENO',
#        'SERRANO', 'BARTLETT', 'ORANGE', 'GREEN', 'RED',
#        'VARIOUS YELLOW FLESH VARIETIES', 'VARIOUS WHITE FLESH VARIETIES',
#        'MARADOL/TAINUNG TYPES', 'VALENCIA', 'NAVEL',
#        'YELLOW MARKED SWEET', 'YELLOW', 'WHITE', 'LONG SEEDLESS',
#        'HEARTS', 'ROUND GREEN TYPE', 'RED TYPE', 'PINK LADY/CRIPPS PINK',
#        'RED DELICIOUS', 'GRANNY SMITH', 'GINGER GOLD', "D'ANJOU", 'BOSC',
#        'PORTOBELLA', 'HONEYCRISP', 'PAULA RED', 'MCINTOSH', 'JONATHAN',
#        'BRAEBURN', 'GALA', 'FUJI', 'HAYWARD', 'WHITE SEEDLESS TYPE',
#        'BLACK SEEDLESS', 'RED SEEDLESS', 'RED GLOBE', 'TURNIP TOPS',
#        'SWISS CHARD', 'MUSTARD', 'COLLARD', 'KALE', 'CACTUS PEARS',
#        'APPLE PEARS', 'RED VARIETIES', 'BABY PEELED', 'BABY HYBRID TYPE',
#        'CROWN CUT', 'VARIOUS GREENSKIN VARIETIES', 'HASS',
#        'JUICE MARKED CIDER', 'JUICE', 'VINE RIPE - HEIRLOOM VARIETIES',
#        'VINE RIPES, ON THE VINE', 'VINE RIPES',
#        'YELLOW CROOKNECK/STRAIGHTNECK', 'SPAGHETTI', 'BUTTERNUT',
#        'ZUCCHINI', 'ACORN', 'GREY', 'ROMA', 'BLACKBERRIES', 'GREEN LEAF',
#        'RED LEAF', 'BOSTON', 'RED FLESH SEEDLESS MINIATURE',
#        'RED FLESH SEEDLESS TYPE', 'RED FLESH SEEDED TYPE',
#        'CACTUS LEAF (NOPALES)', 'FLAT, BABY TYPE', 'MIXED TYPES',
#        'MARKED EXTRA LARGE', 'MINIATURE', 'YELLOW TYPE', 'ROUND WHITE',
#        'SOLO TYPE', 'GOLDEN DELICIOUS', 'RAINIER', 'SATSUMA', 'JONAGOLD',
#        'VL T-BONE STEAK', 'LONGIFLORUM (EASTER LILY)',
#        'VL SHOULDER ROAST', 'LB TOP ROUND ROAST', 'ROME', 'POINSETTIAS',
#        'PIE TYPE', 'MARKED MEDIUM', 'MARKED LARGE', 'MARKED SMALL',
#        'VL RIB RACK', 'VL CUBE STEAK', 'LB RIBS', 'VL TOP ROUND STEAK',
#        'VL BNLS LEG'], dtype=object)

# %%
# What's going on in level_3?
usda_df['level_3'].unique()

# Definitely don't think this is needed
usda_df.drop('level_3', axis=1, inplace=True)

usda_df.head()
# Out:
#    issuing_office report_date  program level_1 level_2    level_4 level_5  \
# 0  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN        NaN     NaN
# 1  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN        NaN     NaN
# 2  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN        NaN     NaN
# 3  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN        NaN     NaN
# 4  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN  ALL SHELL     NaN
#
#   organic specialty unit  ... stores_with_ads  store_outlets  feature_rate  \
# 0      NO       NO   NaN  ...             NaN         5500.0           NaN
# 1      NO       NO   NaN  ...             NaN         5500.0           1.2
# 2      NO       NO   NaN  ...             NaN        29200.0           NaN
# 3      NO       NO   NaN  ...             NaN        29200.0           0.2
# 4      NO       NO   NaN  ...             NaN          100.0           NaN
#
#    special_rate  activity_index  locally_grown_percentage  \
# 0           NaN            65.0                       NaN
# 1           NaN             NaN                       NaN
# 2           NaN            65.0                       NaN
# 3           NaN             NaN                       NaN
# 4          11.0             NaN                       NaN
#
#    weighted_average_price  price_low  price_high  product_quality
# 0                     NaN        NaN         NaN              NaN
# 1                     NaN        NaN         NaN              NaN
# 2                     NaN        NaN         NaN              NaN
# 3                     NaN        NaN         NaN              NaN
# 4                     NaN        NaN         NaN              NaN
#
# [5 rows x 21 columns]

# %%
# How about level_4?
usda_df['level_4'].unique()

# Why does this strike me as potentially actually useful?  How much of this column is Nan?

nan_percentage = usda_df['level_4'].isna().sum() / len(usda_df['level_4']) * 100
print(nan_percentage)

# Hmm... 2/3rds empty, huh?  After further consideration, drop. 
usda_df.drop('level_4', axis=1, inplace=True)

usda_df.head()
# Out:
# 66.77800947490637
#    issuing_office report_date  program level_1 level_2 level_5 organic  \
# 0  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN     NaN      NO
# 1  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN     NaN      NO
# 2  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN     NaN      NO
# 3  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN     NaN      NO
# 4  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN     NaN      NO
#
#   specialty unit          region  stores_with_ads  store_outlets  \
# 0       NO   NaN  NORTHEAST U.S.              NaN         5500.0
# 1       NO   NaN  NORTHEAST U.S.              NaN         5500.0
# 2       NO   NaN        NATIONAL              NaN        29200.0
# 3       NO   NaN        NATIONAL              NaN        29200.0
# 4       NO   NaN          ALASKA              NaN          100.0
#
#    feature_rate  special_rate  activity_index  locally_grown_percentage  \
# 0           NaN           NaN            65.0                       NaN
# 1           1.2           NaN             NaN                       NaN
# 2           NaN           NaN            65.0                       NaN
# 3           0.2           NaN             NaN                       NaN
# 4           NaN          11.0             NaN                       NaN
#
#    weighted_average_price  price_low  price_high product_quality
# 0                     NaN        NaN         NaN             NaN
# 1                     NaN        NaN         NaN             NaN
# 2                     NaN        NaN         NaN             NaN
# 3                     NaN        NaN         NaN             NaN
# 4                     NaN        NaN         NaN             NaN

# %%
# Okay, level_5?
usda_df['level_5'].unique()

# Drop
usda_df.drop('level_5', axis=1, inplace=True)

usda_df.head()
# Out:
#    issuing_office report_date  program level_1 level_2 organic specialty unit  \
# 0  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 1  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 2  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 3  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 4  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
#
#            region  stores_with_ads  store_outlets  feature_rate  special_rate  \
# 0  NORTHEAST U.S.              NaN         5500.0           NaN           NaN
# 1  NORTHEAST U.S.              NaN         5500.0           1.2           NaN
# 2        NATIONAL              NaN        29200.0           NaN           NaN
# 3        NATIONAL              NaN        29200.0           0.2           NaN
# 4          ALASKA              NaN          100.0           NaN          11.0
#
#    activity_index  locally_grown_percentage  weighted_average_price  \
# 0            65.0                       NaN                     NaN
# 1             NaN                       NaN                     NaN
# 2            65.0                       NaN                     NaN
# 3             NaN                       NaN                     NaN
# 4             NaN                       NaN                     NaN
#
#    price_low  price_high product_quality
# 0        NaN         NaN             NaN
# 1        NaN         NaN             NaN
# 2        NaN         NaN             NaN
# 3        NaN         NaN             NaN
# 4        NaN         NaN             NaN

# %%
# Organic?
usda_df['organic'].unique()

# How much NaN?
nan_percentage = usda_df['organic'].isna().sum() / len(usda_df['organic']) * 100
print(nan_percentage)

# Over half?  I'm going to keep it, at present, because I don't know if my other datasets reference organic vs. non-organic
# products, specifically.  If they do, this could still be useful.
# Out:
# 56.39868954924173

# %%
# Speciality?
usda_df['specialty'].unique()

# How much NaN?
nan_percentage = usda_df['specialty'].isna().sum() / len(usda_df['specialty']) * 100
print(nan_percentage)

# Over half, again?  I feel like the Costco dataset might use "specialty" as a marker, as well.  I'll keep for now.
# Out:
# 58.29050461583623

# %%
# Unit?
usda_df['unit'].unique()

# Seems useful to align with actual grocery market data (i.e. Costco dataset)

# How much NaN?
nan_percentage = usda_df['unit'].isna().sum() / len(usda_df['unit']) * 100
print(nan_percentage)

# Pretty complete.  Keep for now.
# Out:
# 11.75014012388586

# %%
# region seems useful, by default.  How many NaN's exist in it, though? 

# How much NaN?
nan_percentage = usda_df['region'].isna().sum() / len(usda_df['region']) * 100
print(nan_percentage)

# Totally complete?  Keep.
# Out:
# 0.0

# %%
# stores_with_ads?
usda_df['stores_with_ads'].unique()

usda_df['stores_with_ads'].nunique()

# So, is this saying *how many* stores run an add for each particular product? 

# How much of this column is NaN?
nan_percentage = usda_df['stores_with_ads'].isna().sum() / len(usda_df['stores_with_ads']) * 100
print(nan_percentage)

# Over half?  I think I'm not going to consider ads in this analysis.  Drop.
usda_df.drop('stores_with_ads', axis=1, inplace=True)

usda_df.head()
# Out:
# 56.39868954924173
#    issuing_office report_date  program level_1 level_2 organic specialty unit  \
# 0  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 1  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 2  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 3  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 4  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
#
#            region  store_outlets  feature_rate  special_rate  activity_index  \
# 0  NORTHEAST U.S.         5500.0           NaN           NaN            65.0
# 1  NORTHEAST U.S.         5500.0           1.2           NaN             NaN
# 2        NATIONAL        29200.0           NaN           NaN            65.0
# 3        NATIONAL        29200.0           0.2           NaN             NaN
# 4          ALASKA          100.0           NaN          11.0             NaN
#
#    locally_grown_percentage  weighted_average_price  price_low  price_high  \
# 0                       NaN                     NaN        NaN         NaN
# 1                       NaN                     NaN        NaN         NaN
# 2                       NaN                     NaN        NaN         NaN
# 3                       NaN                     NaN        NaN         NaN
# 4                       NaN                     NaN        NaN         NaN
#
#   product_quality
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# store_outlets?  I assume this is saying how *many* stores a particular product is in?  Could be useful...

# How empty?
nan_percentage = usda_df['store_outlets'].isna().sum() / len(usda_df['store_outlets']) * 100
print(nan_percentage)

# 88%?  Drop
usda_df.drop('store_outlets', axis=1, inplace=True)

usda_df.head()
# Out:
# 88.24985987611414
#    issuing_office report_date  program level_1 level_2 organic specialty unit  \
# 0  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 1  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 2  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 3  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 4  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
#
#            region  feature_rate  special_rate  activity_index  \
# 0  NORTHEAST U.S.           NaN           NaN            65.0
# 1  NORTHEAST U.S.           1.2           NaN             NaN
# 2        NATIONAL           NaN           NaN            65.0
# 3        NATIONAL           0.2           NaN             NaN
# 4          ALASKA           NaN          11.0             NaN
#
#    locally_grown_percentage  weighted_average_price  price_low  price_high  \
# 0                       NaN                     NaN        NaN         NaN
# 1                       NaN                     NaN        NaN         NaN
# 2                       NaN                     NaN        NaN         NaN
# 3                       NaN                     NaN        NaN         NaN
# 4                       NaN                     NaN        NaN         NaN
#
#   product_quality
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# feature_rate?
usda_df['feature_rate'].unique()

usda_df['feature_rate'].nunique()

# I think, similar to analyzing ads, I'm not going to consider whether a product is "featured" or not in this analysis, but
# rather am just going to keep it to a pretty baseline-analysis of product prices without these other variables, instead.  Drop.

usda_df.drop('feature_rate', axis=1, inplace=True)

usda_df.head()
# Out:
#    issuing_office report_date  program level_1 level_2 organic specialty unit  \
# 0  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 1  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 2  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 3  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 4  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
#
#            region  special_rate  activity_index  locally_grown_percentage  \
# 0  NORTHEAST U.S.           NaN            65.0                       NaN
# 1  NORTHEAST U.S.           NaN             NaN                       NaN
# 2        NATIONAL           NaN            65.0                       NaN
# 3        NATIONAL           NaN             NaN                       NaN
# 4          ALASKA          11.0             NaN                       NaN
#
#    weighted_average_price  price_low  price_high product_quality
# 0                     NaN        NaN         NaN             NaN
# 1                     NaN        NaN         NaN             NaN
# 2                     NaN        NaN         NaN             NaN
# 3                     NaN        NaN         NaN             NaN
# 4                     NaN        NaN         NaN             NaN

# %%
# Same logic applies to special_rate and activity_index

usda_df.drop('special_rate', axis=1, inplace=True)
usda_df.drop('activity_index', axis=1, inplace=True)

usda_df.head()
# Out:
#    issuing_office report_date  program level_1 level_2 organic specialty unit  \
# 0  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 1  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 2  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 3  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 4  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
#
#            region  locally_grown_percentage  weighted_average_price  \
# 0  NORTHEAST U.S.                       NaN                     NaN
# 1  NORTHEAST U.S.                       NaN                     NaN
# 2        NATIONAL                       NaN                     NaN
# 3        NATIONAL                       NaN                     NaN
# 4          ALASKA                       NaN                     NaN
#
#    price_low  price_high product_quality
# 0        NaN         NaN             NaN
# 1        NaN         NaN             NaN
# 2        NaN         NaN             NaN
# 3        NaN         NaN             NaN
# 4        NaN         NaN             NaN

# %%
# I can't see being particularly interested in locally_grown_percentage, but I'm curious how much data is in it...

nan_percentage = usda_df['locally_grown_percentage'].isna().sum() / len(usda_df['locally_grown_percentage']) * 100
print(nan_percentage)

# Useless.  Drop.
usda_df.drop('locally_grown_percentage', axis=1, inplace=True)

usda_df.head()
# Out:
# 99.91705691449286
#    issuing_office report_date  program level_1 level_2 organic specialty unit  \
# 0  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 1  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 2  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 3  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 4  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
#
#            region  weighted_average_price  price_low  price_high  \
# 0  NORTHEAST U.S.                     NaN        NaN         NaN
# 1  NORTHEAST U.S.                     NaN        NaN         NaN
# 2        NATIONAL                     NaN        NaN         NaN
# 3        NATIONAL                     NaN        NaN         NaN
# 4          ALASKA                     NaN        NaN         NaN
#
#   product_quality
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# weighted_average_price seems like it could be useful.  What's going on in it?
nan_percentage = usda_df['weighted_average_price'].isna().sum() / len(usda_df['weighted_average_price']) * 100
print(nan_percentage)

# Guess I'll keep for now.
# Out:
# 11.750159351863335

# %%
# price_low?
nan_percentage = usda_df['price_low'].isna().sum() / len(usda_df['price_low']) * 100
print(nan_percentage)
# Out:
# 33.09371427802309

# %%
# price_high?
nan_percentage = usda_df['price_high'].isna().sum() / len(usda_df['price_high']) * 100
print(nan_percentage)
# Out:
# 33.0485093029762

# %%
# product_quality?
nan_percentage = usda_df['product_quality'].isna().sum() / len(usda_df['product_quality']) * 100
print(nan_percentage)

usda_df['product_quality'].unique()

# Not a consideration in this analysis.  Drop.
usda_df.drop('product_quality', axis=1, inplace=True)

usda_df.head()
# Out:
# 44.2323021689479
#    issuing_office report_date  program level_1 level_2 organic specialty unit  \
# 0  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 1  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 2  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 3  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
# 4  DES MOINES, IA  2024-08-30  POULTRY    EGGS     NaN      NO       NO   NaN
#
#            region  weighted_average_price  price_low  price_high
# 0  NORTHEAST U.S.                     NaN        NaN         NaN
# 1  NORTHEAST U.S.                     NaN        NaN         NaN
# 2        NATIONAL                     NaN        NaN         NaN
# 3        NATIONAL                     NaN        NaN         NaN
# 4          ALASKA                     NaN        NaN         NaN

# %%
# Okay, so what am I left with at this point? 

nan_percentage = usda_df.isna().sum() / len(usda_df) * 100
print(nan_percentage)

# I'm actually pretty happy with this table for the moment.  Good deal *thumbs up*
# Out:
# issuing_office             0.000000
# report_date                0.000000
# program                    0.000000
# level_1                    0.097223
# level_2                    8.058644
# organic                   56.398690
# specialty                 58.290505
# unit                      11.750140
# region                     0.000000
# weighted_average_price    11.750159
# price_low                 33.093714
# price_high                33.048509
# dtype: float64

# %% [markdown]
# ## B. Inflation Trend Data

# %%
# Create a dataframe from the BLS data
bls_df = pd.read_excel('cpi-u-202412.xlsx')

# %%
# Take a look at what needs done
bls_df.head()
# Out:
#   Expenditure category  Relative\nimportance\nNov.\n2024 Unadjusted indexes  \
# 0                  NaN                               NaN         Dec.\n2023
# 1                  NaN                               NaN                NaN
# 2                  NaN                               NaN                NaN
# 3            All items                           100.000            306.746
# 4                 Food                            13.483            325.409
#
#   Unadjusted indexes.1 Unadjusted indexes.2 Unadjusted indexes.3  \
# 0           Jan.\n2024           Feb.\n2024           Mar.\n2024
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3              308.417              310.326              312.332
# 4              327.327              327.731              328.043
#
#   Unadjusted indexes.4 Unadjusted indexes.5 Unadjusted indexes.6  \
# 0           Apr.\n2024            May\n2024           Jun.\n2024
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3              313.548              314.069              314.175
# 4              328.678               329.12               329.71
#
#   Unadjusted indexes.7  ... Seasonally adjusted percent change.1  \
# 0           Jul.\n2024  ...              Oct.\n2024-\nNov.\n2024
# 1                  NaN  ...                                  NaN
# 2                  NaN  ...                                  NaN
# 3               314.54  ...                                  0.3
# 4              330.561  ...                                  0.4
#
#   Seasonally adjusted percent change.2  \
# 0              Nov.\n2024-\nDec.\n2024
# 1                                  NaN
# 2                                  NaN
# 3                                  0.4
# 4                                  0.3
#
#                                            One Month  \
# 0  Seasonally adjusted effect on All Items\nNov. ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              0.042
#
#                               One Month.1  \
# 0  Standard error, median price change(2)
# 1                                     NaN
# 2                                     NaN
# 3                                    0.04
# 4                                    0.08
#
#                                          One Month.2  \
# 0  Largest (L) or Smallest (S) seasonally adjuste...
# 1                                               Date
# 2                                                NaN
# 3                                        L-Mar. 2024
# 4                                        S-Oct. 2024
#
#                                          One Month.3  \
# 0  Largest (L) or Smallest (S) seasonally adjuste...
# 1                                     Percent change
# 2                                                NaN
# 3                                                0.4
# 4                                                0.2
#
#                                         Twelve Month  \
# 0  Unadjusted effect on All Items\nDec. 2023-\nDe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               0.34
#
#                            Twelve Month.1  \
# 0  Standard error, median price change(2)
# 1                                     NaN
# 2                                     NaN
# 3                                     0.1
# 4                                    0.25
#
#                                       Twelve Month.2  \
# 0  Largest (L) or Smallest (S) unadjusted change ...
# 1                                               Date
# 2                                                NaN
# 3                                        L-Jul. 2024
# 4                                        L-Jan. 2024
#
#                                       Twelve Month.3
# 0  Largest (L) or Smallest (S) unadjusted change ...
# 1                                     Percent change
# 2                                                NaN
# 3                                                2.9
# 4                                                2.6
#
# [5 rows x 43 columns]

# %%
# Get rid of indexes.  Will just use summary data.

indexes = bls_df.columns[bls_df.columns.str.contains('index', case=False)]

bls_df.drop(columns=indexes, axis=1, inplace=True)

bls_df.head()
# Out:
#   Expenditure category  Relative\nimportance\nNov.\n2024  \
# 0                  NaN                               NaN
# 1                  NaN                               NaN
# 2                  NaN                               NaN
# 3            All items                           100.000
# 4                 Food                            13.483
#
#   Unadjusted percent change Unadjusted percent change.1  \
# 0   Dec.\n2023-\nDec.\n2024     Sep.\n2024-\nOct.\n2024
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       2.9                         0.1
# 4                       2.5                         0.2
#
#   Unadjusted percent change.2 Unadjusted percent change.3  \
# 0     Oct.\n2024-\nNov.\n2024     Nov.\n2024-\nDec.\n2024
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                        -0.1                           0
# 4                         0.1                         0.2
#
#   Seasonally adjusted percent change Seasonally adjusted percent change.1  \
# 0            Sep.\n2024-\nOct.\n2024              Oct.\n2024-\nNov.\n2024
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                0.2                                  0.3
# 4                                0.2                                  0.4
#
#   Seasonally adjusted percent change.2  \
# 0              Nov.\n2024-\nDec.\n2024
# 1                                  NaN
# 2                                  NaN
# 3                                  0.4
# 4                                  0.3
#
#                                            One Month  \
# 0  Seasonally adjusted effect on All Items\nNov. ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              0.042
#
#                               One Month.1  \
# 0  Standard error, median price change(2)
# 1                                     NaN
# 2                                     NaN
# 3                                    0.04
# 4                                    0.08
#
#                                          One Month.2  \
# 0  Largest (L) or Smallest (S) seasonally adjuste...
# 1                                               Date
# 2                                                NaN
# 3                                        L-Mar. 2024
# 4                                        S-Oct. 2024
#
#                                          One Month.3  \
# 0  Largest (L) or Smallest (S) seasonally adjuste...
# 1                                     Percent change
# 2                                                NaN
# 3                                                0.4
# 4                                                0.2
#
#                                         Twelve Month  \
# 0  Unadjusted effect on All Items\nDec. 2023-\nDe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               0.34
#
#                            Twelve Month.1  \
# 0  Standard error, median price change(2)
# 1                                     NaN
# 2                                     NaN
# 3                                     0.1
# 4                                    0.25
#
#                                       Twelve Month.2  \
# 0  Largest (L) or Smallest (S) unadjusted change ...
# 1                                               Date
# 2                                                NaN
# 3                                        L-Jul. 2024
# 4                                        L-Jan. 2024
#
#                                       Twelve Month.3
# 0  Largest (L) or Smallest (S) unadjusted change ...
# 1                                     Percent change
# 2                                                NaN
# 3                                                2.9
# 4                                                2.6

# %%
# I only care about the percent changes year-over-year, not month-to-month

bls_df.drop('Unadjusted percent change.1', axis=1, inplace=True)
bls_df.drop('Unadjusted percent change.2', axis=1, inplace=True)
bls_df.drop('Unadjusted percent change.3', axis=1, inplace=True)
bls_df.drop('Seasonally adjusted percent change', axis=1, inplace=True)
bls_df.drop('Seasonally adjusted percent change.1', axis=1, inplace=True)
bls_df.drop('Seasonally adjusted percent change.2', axis=1, inplace=True)

bls_df.head()
# Out:
#   Expenditure category  Relative\nimportance\nNov.\n2024  \
# 0                  NaN                               NaN
# 1                  NaN                               NaN
# 2                  NaN                               NaN
# 3            All items                           100.000
# 4                 Food                            13.483
#
#   Unadjusted percent change  \
# 0   Dec.\n2023-\nDec.\n2024
# 1                       NaN
# 2                       NaN
# 3                       2.9
# 4                       2.5
#
#                                            One Month  \
# 0  Seasonally adjusted effect on All Items\nNov. ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              0.042
#
#                               One Month.1  \
# 0  Standard error, median price change(2)
# 1                                     NaN
# 2                                     NaN
# 3                                    0.04
# 4                                    0.08
#
#                                          One Month.2  \
# 0  Largest (L) or Smallest (S) seasonally adjuste...
# 1                                               Date
# 2                                                NaN
# 3                                        L-Mar. 2024
# 4                                        S-Oct. 2024
#
#                                          One Month.3  \
# 0  Largest (L) or Smallest (S) seasonally adjuste...
# 1                                     Percent change
# 2                                                NaN
# 3                                                0.4
# 4                                                0.2
#
#                                         Twelve Month  \
# 0  Unadjusted effect on All Items\nDec. 2023-\nDe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               0.34
#
#                            Twelve Month.1  \
# 0  Standard error, median price change(2)
# 1                                     NaN
# 2                                     NaN
# 3                                     0.1
# 4                                    0.25
#
#                                       Twelve Month.2  \
# 0  Largest (L) or Smallest (S) unadjusted change ...
# 1                                               Date
# 2                                                NaN
# 3                                        L-Jul. 2024
# 4                                        L-Jan. 2024
#
#                                       Twelve Month.3
# 0  Largest (L) or Smallest (S) unadjusted change ...
# 1                                     Percent change
# 2                                                NaN
# 3                                                2.9
# 4                                                2.6

# %%
# Don't need 'relative importance'.

bls_df.drop('Relative\nimportance\nNov.\n2024', axis=1, inplace=True)

bls_df.head()
# Out:
#   Expenditure category Unadjusted percent change  \
# 0                  NaN   Dec.\n2023-\nDec.\n2024
# 1                  NaN                       NaN
# 2                  NaN                       NaN
# 3            All items                       2.9
# 4                 Food                       2.5
#
#                                            One Month  \
# 0  Seasonally adjusted effect on All Items\nNov. ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              0.042
#
#                               One Month.1  \
# 0  Standard error, median price change(2)
# 1                                     NaN
# 2                                     NaN
# 3                                    0.04
# 4                                    0.08
#
#                                          One Month.2  \
# 0  Largest (L) or Smallest (S) seasonally adjuste...
# 1                                               Date
# 2                                                NaN
# 3                                        L-Mar. 2024
# 4                                        S-Oct. 2024
#
#                                          One Month.3  \
# 0  Largest (L) or Smallest (S) seasonally adjuste...
# 1                                     Percent change
# 2                                                NaN
# 3                                                0.4
# 4                                                0.2
#
#                                         Twelve Month  \
# 0  Unadjusted effect on All Items\nDec. 2023-\nDe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               0.34
#
#                            Twelve Month.1  \
# 0  Standard error, median price change(2)
# 1                                     NaN
# 2                                     NaN
# 3                                     0.1
# 4                                    0.25
#
#                                       Twelve Month.2  \
# 0  Largest (L) or Smallest (S) unadjusted change ...
# 1                                               Date
# 2                                                NaN
# 3                                        L-Jul. 2024
# 4                                        L-Jan. 2024
#
#                                       Twelve Month.3
# 0  Largest (L) or Smallest (S) unadjusted change ...
# 1                                     Percent change
# 2                                                NaN
# 3                                                2.9
# 4                                                2.6

# %%
# Don't need margins of error, or largest / smallest.

bls_df.drop('One Month.1', axis=1, inplace=True)
bls_df.drop('One Month.2', axis=1, inplace=True)
bls_df.drop('One Month.3', axis=1, inplace=True)
bls_df.drop('Twelve Month.1', axis=1, inplace=True)
bls_df.drop('Twelve Month.2', axis=1, inplace=True)
bls_df.drop('Twelve Month.3', axis=1, inplace=True)

bls_df.head()

# This actually looks a lot better.  I need to rename the columns more helpfully, though...
# Out:
#   Expenditure category Unadjusted percent change  \
# 0                  NaN   Dec.\n2023-\nDec.\n2024
# 1                  NaN                       NaN
# 2                  NaN                       NaN
# 3            All items                       2.9
# 4                 Food                       2.5
#
#                                            One Month  \
# 0  Seasonally adjusted effect on All Items\nNov. ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              0.042
#
#                                         Twelve Month
# 0  Unadjusted effect on All Items\nDec. 2023-\nDe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               0.34

# %%
bls_df.columns = [
    'product',
    'unadjusted_percent_change_2024',
    'seasonally_adjusted_effect_2024', 
    'unadjusted_effect_2024'
]

bls_df.head()
# Out:
#      product unadjusted_percent_change_2024  \
# 0        NaN        Dec.\n2023-\nDec.\n2024
# 1        NaN                            NaN
# 2        NaN                            NaN
# 3  All items                            2.9
# 4       Food                            2.5
#
#                      seasonally_adjusted_effect_2024  \
# 0  Seasonally adjusted effect on All Items\nNov. ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              0.042
#
#                               unadjusted_effect_2024
# 0  Unadjusted effect on All Items\nDec. 2023-\nDe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               0.34

# %%
# Do rows 1 and 2 contain any data?

rows_to_check = [1, 2]
are_all_nan = bls_df.loc[rows_to_check].isna().all().all()

print(are_all_nan)

# They're empty.  Drop them, and I suppose all other completely empty rows, as well. 

bls_df = bls_df.dropna(how='all')

bls_df.head()

# Oh, and we don't need the "sub-heading" row, now that the headings are improved. 

bls_df = bls_df.drop(index=0)

bls_df.head()

# Alright!  This is starting to look way more usable! *thumbs up*
# Out:
#                        product unadjusted_percent_change_2024  \
# 3                    All items                            2.9
# 4                         Food                            2.5
# 5                 Food at home                            1.8
# 6  Cereals and bakery products                            0.8
# 7  Cereals and cereal products                            1.7
#
#   seasonally_adjusted_effect_2024 unadjusted_effect_2024
# 3                             NaN                    NaN
# 4                           0.042                   0.34
# 5                           0.026                  0.145
# 6                           0.012                  0.008
# 7                           0.004                  0.005
